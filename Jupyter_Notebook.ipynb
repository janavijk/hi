# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
#notebook

# %% [markdown]
# notebook

# %% [markdown]
# #introduction

# %% [markdown]
# list of data science languages
# R.
# SQL.
# Java.
# Julia.
# Scala.
# JavaScript
# Swift.

# %% [markdown]
# list of data science libraries
# TensorFlow
# NumPy
# SciPy
# Pandas
# Matplotlib
# Keras
# SciKit-Learn
# PyTorch

# %% [markdown]
# data science tools
# SAS
# BigML.
# Knime.
# Tableau.
# TensorFlow.
# Snowflake.

# %% [markdown]
# introoduction to arithmetic expression

# %%
a=10
b=10
mul=a*b
add=a+b
print(mul)
print(add)

# %%
#minutes to hours
min=200
hrs=200*60
print(hrs)

# %% [markdown]
# objectives
# what are data science languages used
# data science tools
# data science libraries
# addition and multiplication of two numbers
# conversion from minutes to hours

# %% [markdown]
# author name-janavi j
